# %% [markdown]
# ## The Sparks Foundation
#
# ### Graduate Rotational Internship Programme (GRIP)
#
# #### `MAY 2023 Batch`
# #### `Candidate Name : Mayur Korde`
#
# ### Task_8 : Timeline Analysis_Covid 19

# %%
import pandas as pd
import numpy as np
import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.style.use('fivethirtyeight')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
covid_df = pd.read_csv('owid-covid-data.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
covid_df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         0.0                  NaN
# 1                 NaN           NaN         0.0                  NaN
# 2                 NaN           NaN         0.0                  NaN
# 3                 NaN           NaN         0.0                  NaN
# 4                 NaN           NaN         0.0                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                      NaN                    0.0
# ...

# %%
covid_df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 311302      ZWE    Africa  Zimbabwe  2023-05-13     264821.0        5.0
# 311303      ZWE    Africa  Zimbabwe  2023-05-14     264841.0       20.0
# 311304      ZWE    Africa  Zimbabwe  2023-05-15     264848.0        7.0
# 311305      ZWE    Africa  Zimbabwe  2023-05-16     264848.0        0.0
# 311306      ZWE    Africa  Zimbabwe  2023-05-17     264848.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 311302              10.286        5690.0         1.0                0.429
# 311303              10.714        5690.0         0.0                0.429
# 311304              10.286        5690.0         0.0                0.286
# 311305               9.429        5690.0         0.0                0.286
# 311306               8.143        5690.0         0.0                0.143
#
#         total_cases_per_million  new_cases_per_million  \
# ...

# %%
covid_df.shape
# Out:
# (311307, 67)

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311307 entries, 0 to 311306
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    311307 non-null  object
#  1   continent                                   296535 non-null  object
#  2   location                                    311307 non-null  object
#  3   date                                        311307 non-null  object
#  4   total_cases                                 275335 non-null  float64
#  5   new_cases                                   302655 non-null  float64
#  6   new_cases_smoothed                          301391 non-null  float64
#  7   total_deaths                                254635 non-null  float64
#  8   new_deaths                                  302735 non-null  float64
# ...

# %%
covid_df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   14772
# location                                        0
# date                                            0
# total_cases                                 35972
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       300638
# excess_mortality_cumulative                300638
# excess_mortality                           300638
# excess_mortality_cumulative_per_million    300638
# Length: 67, dtype: int64

# %%
covid_df.duplicated().sum()
# Out:
# 0

# %%
covid_df['continent'].value_counts()
# Out:
# Africa           70168
# Europe           67374
# Asia             61741
# North America    50473
# Oceania          29544
# South America    17235
# Name: continent, dtype: int64

# %%
covid_df['location'].value_counts()
# Out:
# Argentina          1233
# Mexico             1233
# Afghanistan        1231
# Palau              1231
# Nicaragua          1231
#                    ...
# Scotland           1145
# Wales              1135
# Macao               795
# Northern Cyprus     691
# Western Sahara        1
# Name: location, Length: 255, dtype: int64

# %%
covid_df.cov()
# Out:
#                                           total_cases     new_cases  \
# total_cases                              1.296063e+15  1.885016e+12
# new_cases                                1.885016e+12  1.061075e+10
# new_cases_smoothed                       1.917966e+12  9.853941e+09
# total_deaths                             1.454318e+13  2.479494e+10
# new_deaths                               8.493735e+09  3.047450e+07
# ...                                               ...           ...
# population                               1.592047e+16  3.053027e+13
# excess_mortality_cumulative_absolute     9.502464e+11  1.382898e+09
# excess_mortality_cumulative              8.555924e+06  1.144199e+04
# excess_mortality                        -6.966008e+06  4.527153e+04
# excess_mortality_cumulative_per_million  2.979943e+09  1.651008e+06
#
#                                          new_cases_smoothed  total_deaths  \
# total_cases                                    1.917966e+12  1.454318e+13
# ...

# %%
covid_df.corr()
# Out:
#                                          total_cases  new_cases  \
# total_cases                                 1.000000   0.484842
# new_cases                                   0.484842   1.000000
# new_cases_smoothed                          0.507853   0.952298
# total_deaths                                0.933713   0.530433
# new_deaths                                  0.374941   0.492393
# ...                                              ...        ...
# population                                  0.633013   0.443328
# excess_mortality_cumulative_absolute        0.766427   0.334512
# excess_mortality_cumulative                 0.076898   0.029723
# excess_mortality                           -0.030168   0.058148
# excess_mortality_cumulative_per_million     0.183680   0.030092
#
#                                          new_cases_smoothed  total_deaths  \
# total_cases                                        0.507853      0.933713
# ...

# %%
covid_df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.753350e+05  3.026550e+05        3.013910e+05  2.546350e+05
# mean   5.767156e+06  1.073397e+04        1.077678e+04  8.061661e+04
# std    3.600088e+07  1.030085e+05        1.002455e+05  4.164645e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    6.565000e+03  0.000000e+00        1.143000e+00  1.210000e+02
# 50%    6.239700e+04  1.700000e+01        3.771400e+01  1.230000e+03
# 75%    6.419815e+05  5.230000e+02        6.310000e+02  1.064800e+04
# max    7.664400e+08  7.460822e+06        6.410667e+06  6.932578e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  302735.000000        301505.000000            275335.000000
# mean       95.740952            96.103652             88010.375666
# std       600.706338           591.334247            138439.520139
# min         0.000000             0.000000                 0.000000
# ...

# %% [markdown]
# `KPI`

# %%
covid_df['total_cases'].value_counts().sum()
# Out:
# 275335

# %%
covid_df['new_cases'].value_counts().sum()
# Out:
# 302655

# %%
covid_df['total_deaths'].value_counts().sum()
# Out:
# 254635

# %%
covid_df['new_deaths'].value_counts().sum()
# Out:
# 302735

# %%
covid_df['icu_patients'].value_counts().sum()
# Out:
# 35962

# %%
covid_df['hosp_patients'].value_counts().sum()
# Out:
# 36744

# %%
covid_df['total_tests'].value_counts().sum()
# Out:
# 79387

# %%
covid_df['new_tests'].value_counts().sum()
# Out:
# 75403

# %%
covid_df['positive_rate'].value_counts().sum()
# Out:
# 95927

# %%
covid_df['total_vaccinations'].value_counts().sum()
# Out:
# 74875

# %%
covid_df['people_vaccinated'].value_counts().sum()
# Out:
# 71723

# %%
covid_df['people_fully_vaccinated'].value_counts().sum()
# Out:
# 69493

# %%
covid_df['total_boosters'].value_counts().sum()
# Out:
# 43506

# %%
covid_df['new_vaccinations'].value_counts().sum()
# Out:
# 61632

# %%
covid_df['female_smokers'].value_counts().sum()
# Out:
# 180960

# %%
covid_df['male_smokers'].value_counts().sum()
# Out:
# 178498

# %% [markdown]
# `Analysis`

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['total_cases'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['new_cases'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['total_deaths'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['new_deaths'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['icu_patients'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['hosp_patients'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['total_tests'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['new_tests'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['positive_rate'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['total_vaccinations'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['people_vaccinated'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['people_fully_vaccinated'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['total_boosters'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['new_vaccinations'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['female_smokers'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(covid_df['continent'], covid_df['male_smokers'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['male_smokers'], covid_df['total_cases'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['female_smokers'], covid_df['total_cases'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['male_smokers'], covid_df['new_cases'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['female_smokers'], covid_df['new_cases'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['male_smokers'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['female_smokers'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['male_smokers'], covid_df['new_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['female_smokers'], covid_df['new_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['total_tests'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['new_tests'], covid_df['new_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['positive_rate'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['positive_rate'], covid_df['new_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['total_vaccinations'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['people_vaccinated'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['people_fully_vaccinated'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['total_boosters'], covid_df['total_deaths'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(covid_df['new_vaccinations'], covid_df['total_deaths'], color='red')
plt.show()

# %% [markdown]
# `Timeline Analysis`

# %%
covid_df['date'] = pd.to_datetime(covid_df['date'])

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['total_deaths'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['total_tests'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['people_fully_vaccinated'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['new_cases'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['new_deaths'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['icu_patients'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['hosp_patients'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['new_tests'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['positive_rate'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['total_vaccinations'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['people_vaccinated'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['total_boosters'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['new_vaccinations'], covid_df['date'], color='red')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['total_vaccinations'], covid_df['total_deaths'], hue=covid_df['continent'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['new_vaccinations'], covid_df['new_deaths'], hue=covid_df['continent'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['hosp_patients'], covid_df['icu_patients'], hue=covid_df['continent'], palette='Set2')
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(covid_df['total_tests'], covid_df['positive_rate'], hue=covid_df['continent'], palette='Set2')
plt.show()

# %% [markdown]
# #### `Thank You`
